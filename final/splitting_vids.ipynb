# %%
from videoretrieval import get_all_videos
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# %%
folder_url = "https://drive.google.com/drive/u/1/folders/1k6SQ88HXatRffBYvx2L6yvtfxppBFKMS"
output_dir = "./videos"
#get_all_videos(folder_url, output_dir)
# Out:
# 100%|██████████| 171M/171M [00:11<00:00, 15.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17NuYmRyLOV4zdGWviCrPITOhbn80lz8Z
# To: /Users/tanishasingh/Documents copy/UCI/Y3Q3/117_final/final/videos/IMG_2261.MOV
# 100%|██████████| 91.9M/91.9M [00:05<00:00, 16.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1ldDSye5q0c_OhRCtKCN-UJsNAGM27Et2
# From (redirected): https://drive.google.com/uc?id=1ldDSye5q0c_OhRCtKCN-UJsNAGM27Et2&confirm=t&uuid=0eeb214b-2fb8-49b2-98f4-329e03068b6e
# To: /Users/tanishasingh/Documents copy/UCI/Y3Q3/117_final/final/videos/IMG_2262.MOV
# 100%|██████████| 112M/112M [00:06<00:00, 16.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1frj7Ildi8hwBAQFnTAW3oejcefKrYg-F
# To: /Users/tanishasingh/Documents copy/UCI/Y3Q3/117_final/final/videos/IMG_2263.MOV
# 100%|██████████| 34.0M/34.0M [00:02<00:00, 15.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1epptXK-tIJ_LvsPxWNFMCsAZQGvOTkXc
# ...

# %%
ffmpeg_extract_subclip(inputfile='videos/IMG_2278.MOV', start_time=0, end_time=5, outputfile='videos/IMG_2278_1.MOV')
# Out:
# MoviePy - Running:
# >>> /Users/tanishasingh/Documents copy/UCI/Y3Q3/117_final/.venv/lib/python3.12/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i videos/IMG_2278.MOV -t 5.00 -map 0 -vcodec copy -acodec copy -copyts videos/IMG_2278_1.MOV
# MoviePy - Command successful
